# %%
import os
os.environ["WANDB_API_KEY"] = "6defbba5bfdc56d6a107d902efbd75dc5660fc2d"
# !git clone https://github.com/Nickmasta/CPEN455FinalProj.git
# %cd CPEN455FinalProj
# !pip install -r requirements.txt
# !python pcnn_train.py --dataset cpen455 --nr_resnet 1 --nr_filters 80 --batch_size 16 --sample_batch_size 16 --lr_decay 0.999995 --max_epochs 20 --sampling_interval 10 --save_interval 10 --en_wandb True
# Out:
# Cloning into 'CPEN455FinalProj'...
# remote: Enumerating objects: 5251, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 5251 (delta 16), reused 6 (delta 6), pack-reused 5214 (from 2)
# Receiving objects: 100% (5251/5251), 9.13 MiB | 18.88 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# /kaggle/working/CPEN455FinalProj
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.1 MB/s eta 0:00:00
# ...

# %%
import os
# !git clone https://github.com/Nickmasta/CPEN455FinalProj.git
# %cd CPEN455FinalProj
# !python generation_evaluation.py
# Out:
# Cloning into 'CPEN455FinalProj'...
# remote: Enumerating objects: 5251, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 5251 (delta 16), reused 6 (delta 6), pack-reused 5214 (from 2)
# Receiving objects: 100% (5251/5251), 9.13 MiB | 34.62 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# /kaggle/working/CPEN455FinalProj/CPEN455FinalProj
# /usr/local/lib/python3.11/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Label: 0
# Traceback (most recent call last):
#   File "/kaggle/working/CPEN455FinalProj/CPEN455FinalProj/generation_evaluation.py", line 58, in <module>
#     my_sample(model=model, gen_data_dir=gen_data_dir)
#   File "/kaggle/working/CPEN455FinalProj/CPEN455FinalProj/generation_evaluation.py", line 30, in my_sample
# ...
